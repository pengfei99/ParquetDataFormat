# %% [markdown]
# # Special characters in the Parquet files
#
# Parquet file does not store plain text data, it only stores binary data, and the encoding of textual data is not explicitly managed by the Parquet file. The interpretation of those bytes as characters is left to the reading application (like Pandas, spark, etc.).
# based on the encoding used by that application.
#
# If you're experiencing issues with textual data in Parquet files, **it must be related to the way the data was initially written to the Parquet files**, rather than how Pandas or Spark is reading it.
#
# > Ensure that the data is written correctly with appropriate encodings to the Parquet files in the first place. If the data was written correctly, we should be able to read it correctly as well.
# >
#
# Below are two examples,
#
# - In example 1, we read a parquet file that is written with bad encoding.
# - In example 2, we create a parquet file with special characters with good encoding.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import os
import pandas as pd

# %%
local=True
if local:
    spark=SparkSession.builder.master("local[4]") \
                  .appName("ReadWriteParquet").getOrCreate()
else:
    spark=SparkSession.builder \
                      .master("k8s://https://kubernetes.default.svc:443") \
                      .appName("ReadWriteParquet") \
                      .config("spark.kubernetes.container.image","inseefrlab/jupyter-datascience:master") \
                      .config("spark.kubernetes.authenticate.driver.serviceAccountName",os.environ['KUBERNETES_SERVICE_ACCOUNT']) \
                      .config("spark.kubernetes.namespace", os.environ['KUBERNETES_NAMESPACE']) \
                      .config("spark.executor.instances", "4") \
                      .config("spark.executor.memory","8g") \
                      .config("spark.kubernetes.driver.pod.name", os.environ["POD_NAME"]) \
                      .config('spark.jars.packages','org.postgresql:postgresql:42.2.24') \
                      .getOrCreate()

# %%
! wget https://s3.amazonaws.com/duckdb-md-dataset-121/netflix_daily_top_10.parquet
# Out:
# --2023-08-29 13:16:58--  https://s3.amazonaws.com/duckdb-md-dataset-121/netflix_daily_top_10.parquet
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.38.8, 52.217.86.198, 52.217.164.176, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.38.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92595 (90K) [binary/octet-stream]
# Saving to: ‘netflix_daily_top_10.parquet.1’
#
# netflix_daily_top_1 100%[===================>]  90.42K   150KB/s    in 0.6s
#
# 2023-08-29 13:17:00 (150 KB/s) - ‘netflix_daily_top_10.parquet.1’ saved [92595/92595]

# %% [markdown]
# ## Example 1
#
# Read the downloaded parquet file with pandas

# %%
filePath = "/home/onyxia/work/netflix_daily_top_10.parquet"

pdf = pd.read_parquet(filePath)

# %%
filteredPdf = pdf[pdf['Title'].str.contains('Queen', case=False)]
filteredPdf.head(50)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 699   2020-06-09    10                 -              -
# 709   2020-06-10    10                10              -
# 718   2020-06-11     9                10              -
# 728   2020-06-12     9                 9              -
# 1631  2020-09-11     2                 -              -
# 1641  2020-09-12     2                 2              -
# 1652  2020-09-13     3                 2              -
# 1663  2020-09-14     4                 3              -
# 1675  2020-09-15     6                 4              -
# 1685  2020-09-16     6                 6              -
# 2069  2020-10-24    10                 -              -
# 2070  2020-10-25     1                10              -
# 2080  2020-10-26     1                 1              -
# 2090  2020-10-27     1                 1              -
# 2100  2020-10-28     1                 1              -
# 2111  2020-10-29     2                 1              -
# 2121  2020-10-30     2                 2              -
# 2131  2020-10-31     2                 2             10
# 2141  2020-11-01     2                 2              1
# 2151  2020-11-02     2                 2              1
# 2160  2020-11-03     1                 2              1
# 2170  2020-11-04     1                 1              1
# 2180  2020-11-05     1                 1              2
# 2190  2020-11-06     1                 1              2
# 2200  2020-11-07     1                 1              2
# 2210  2020-11-08     1                 1              2
# 2220  2020-11-09     1                 1              2
# 2230  2020-11-10     1                 1              1
# 2240  2020-11-11     1                 1              1
# 2250  2020-11-12     1                 1              1
# 2260  2020-11-13     1                 1              1
# 2270  2020-11-14     1                 1              1
# 2280  2020-11-15     1                 1              1
# 2291  2020-11-16     2                 1              1
# 2301  2020-11-17     2                 2              1
# 2312  2020-11-18     3                 2              1
# 2322  2020-11-19     3                 3              1
# 2333  2020-11-20     4                 3              1
# 2343  2020-11-21     4                 4              1
# 2353  2020-11-22     4                 4              1
# 2362  2020-11-23     3                 4              2
# 2371  2020-11-24     2                 3              2
# 2382  2020-11-25     3                 2              3
# 2393  2020-11-26     4                 3              3
# 2403  2020-11-27     4                 4              4
# 2413  2020-11-28     4                 4              4
# 2422  2020-11-29     3                 4              4
# 2432  2020-11-30     3                 3              3
# 2443  2020-12-01     4                 3              2
# 2453  2020-12-02     4                 4              3
#
#                              Title     Type Netflix Exclusive  \
# 699             Queen of the South  TV Show              None
# 709             Queen of the South  TV Show              None
# 718             Queen of the South  TV Show              None
# 728             Queen of the South  TV Show              None
# 1631  The Babysitter: Killer Queen    Movie               Yes
# 1641  The Babysitter: Killer Queen    Movie               Yes
# 1652  The Babysitter: Killer Queen    Movie               Yes
# 1663  The Babysitter: Killer Queen    Movie               Yes
# 1675  The Babysitter: Killer Queen    Movie               Yes
# 1685  The Babysitter: Killer Queen    Movie               Yes
# 2069          The Queenâs Gambit  TV Show               Yes
# 2070          The Queenâs Gambit  TV Show               Yes
# 2080          The Queenâs Gambit  TV Show               Yes
# 2090          The Queenâs Gambit  TV Show               Yes
# 2100          The Queenâs Gambit  TV Show               Yes
# 2111          The Queenâs Gambit  TV Show               Yes
# 2121          The Queenâs Gambit  TV Show               Yes
# 2131          The Queenâs Gambit  TV Show               Yes
# 2141          The Queenâs Gambit  TV Show               Yes
# 2151          The Queenâs Gambit  TV Show               Yes
# 2160          The Queenâs Gambit  TV Show               Yes
# 2170          The Queenâs Gambit  TV Show               Yes
# 2180          The Queenâs Gambit  TV Show               Yes
# 2190          The Queenâs Gambit  TV Show               Yes
# 2200          The Queenâs Gambit  TV Show               Yes
# 2210          The Queenâs Gambit  TV Show               Yes
# 2220          The Queenâs Gambit  TV Show               Yes
# 2230          The Queenâs Gambit  TV Show               Yes
# 2240          The Queenâs Gambit  TV Show               Yes
# 2250          The Queenâs Gambit  TV Show               Yes
# 2260          The Queenâs Gambit  TV Show               Yes
# 2270          The Queenâs Gambit  TV Show               Yes
# 2280          The Queenâs Gambit  TV Show               Yes
# 2291          The Queenâs Gambit  TV Show               Yes
# 2301          The Queenâs Gambit  TV Show               Yes
# 2312          The Queenâs Gambit  TV Show               Yes
# 2322          The Queenâs Gambit  TV Show               Yes
# 2333          The Queenâs Gambit  TV Show               Yes
# 2343          The Queenâs Gambit  TV Show               Yes
# 2353          The Queenâs Gambit  TV Show               Yes
# 2362          The Queenâs Gambit  TV Show               Yes
# 2371          The Queenâs Gambit  TV Show               Yes
# 2382          The Queenâs Gambit  TV Show               Yes
# 2393          The Queenâs Gambit  TV Show               Yes
# 2403          The Queenâs Gambit  TV Show               Yes
# 2413          The Queenâs Gambit  TV Show               Yes
# 2422          The Queenâs Gambit  TV Show               Yes
# 2432          The Queenâs Gambit  TV Show               Yes
# 2443          The Queenâs Gambit  TV Show               Yes
# 2453          The Queenâs Gambit  TV Show               Yes
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 699           May 9, 2017               1                 1
# 709           May 9, 2017               2                 2
# 718           May 9, 2017               3                 4
# 728           May 9, 2017               4                 6
# 1631         Sep 10, 2020               1                 9
# 1641         Sep 10, 2020               2                18
# 1652         Sep 10, 2020               3                26
# 1663         Sep 10, 2020               4                33
# 1675         Sep 10, 2020               5                38
# 1685         Sep 10, 2020               6                43
# 2069         Oct 23, 2020               1                 1
# 2070         Oct 23, 2020               2                11
# 2080         Oct 23, 2020               3                21
# 2090         Oct 23, 2020               4                31
# 2100         Oct 23, 2020               5                41
# 2111         Oct 23, 2020               6                50
# 2121         Oct 23, 2020               7                59
# 2131         Oct 23, 2020               8                68
# 2141         Oct 23, 2020               9                77
# 2151         Oct 23, 2020              10                86
# 2160         Oct 23, 2020              11                96
# 2170         Oct 23, 2020              12               106
# 2180         Oct 23, 2020              13               116
# 2190         Oct 23, 2020              14               126
# 2200         Oct 23, 2020              15               136
# 2210         Oct 23, 2020              16               146
# 2220         Oct 23, 2020              17               156
# 2230         Oct 23, 2020              18               166
# 2240         Oct 23, 2020              19               176
# 2250         Oct 23, 2020              20               186
# 2260         Oct 23, 2020              21               196
# 2270         Oct 23, 2020              22               206
# 2280         Oct 23, 2020              23               216
# 2291         Oct 23, 2020              24               225
# 2301         Oct 23, 2020              25               234
# 2312         Oct 23, 2020              26               242
# 2322         Oct 23, 2020              27               250
# 2333         Oct 23, 2020              28               257
# 2343         Oct 23, 2020              29               264
# 2353         Oct 23, 2020              30               271
# 2362         Oct 23, 2020              31               279
# 2371         Oct 23, 2020              32               288
# 2382         Oct 23, 2020              33               296
# 2393         Oct 23, 2020              34               303
# 2403         Oct 23, 2020              35               310
# 2413         Oct 23, 2020              36               317
# 2422         Oct 23, 2020              37               325
# 2432         Oct 23, 2020              38               333
# 2443         Oct 23, 2020              39               340
# 2453         Oct 23, 2020              40               347

# %% [markdown]
# ### Read the parquet file with spark

# %%
df = spark.read.parquet(filePath)
df.show(5)
# Out:
# +----------+----+-----------------+--------------+--------------------+-------+-----------------+--------------------+--------------+----------------+
# |     As of|Rank|Year to Date Rank|Last Week Rank|               Title|   Type|Netflix Exclusive|Netflix Release Date|Days In Top 10|Viewership Score|
# +----------+----+-----------------+--------------+--------------------+-------+-----------------+--------------------+--------------+----------------+
# |2020-04-01|   1|                1|             1|Tiger King: Murde...|TV Show|              Yes|        Mar 20, 2020|             9|              90|
# |2020-04-01|   2|                2|             -|               Ozark|TV Show|              Yes|        Jul 21, 2017|             5|              45|
# |2020-04-01|   3|                3|             2|        All American|TV Show|             null|        Mar 28, 2019|             9|              76|
# |2020-04-01|   4|                4|             -|        Blood Father|  Movie|             null|        Mar 26, 2020|             5|              30|
# |2020-04-01|   5|                5|             4|        The Platform|  Movie|              Yes|        Mar 20, 2020|             9|              55|
# +----------+----+-----------------+--------------+--------------------+-------+-----------------+--------------------+--------------+----------------+
# only showing top 5 rows

# %%
filterDf = df.filter(col("Title").like("%Queen%"))
filterDf.show(50,truncate=False)
# Out:
# +----------+----+-----------------+--------------+----------------------------+-------+-----------------+--------------------+--------------+----------------+
# |As of     |Rank|Year to Date Rank|Last Week Rank|Title                       |Type   |Netflix Exclusive|Netflix Release Date|Days In Top 10|Viewership Score|
# +----------+----+-----------------+--------------+----------------------------+-------+-----------------+--------------------+--------------+----------------+
# |2020-06-09|10  |-                |-             |Queen of the South          |TV Show|null             |May 9, 2017         |1             |1               |
# |2020-06-10|10  |10               |-             |Queen of the South          |TV Show|null             |May 9, 2017         |2             |2               |
# |2020-06-11|9   |10               |-             |Queen of the South          |TV Show|null             |May 9, 2017         |3             |4               |
# |2020-06-12|9   |9                |-             |Queen of the South          |TV Show|null             |May 9, 2017         |4             |6               |
# |2020-09-11|2   |-                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |1             |9               |
# |2020-09-12|2   |2                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |2             |18              |
# |2020-09-13|3   |2                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |3             |26              |
# |2020-09-14|4   |3                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |4             |33              |
# |2020-09-15|6   |4                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |5             |38              |
# |2020-09-16|6   |6                |-             |The Babysitter: Killer Queen|Movie  |Yes              |Sep 10, 2020        |6             |43              |
# |2020-10-24|10  |-                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |1             |1               |
# |2020-10-25|1   |10               |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |2             |11              |
# |2020-10-26|1   |1                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |3             |21              |
# |2020-10-27|1   |1                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |4             |31              |
# |2020-10-28|1   |1                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |5             |41              |
# |2020-10-29|2   |1                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |6             |50              |
# |2020-10-30|2   |2                |-             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |7             |59              |
# |2020-10-31|2   |2                |10            |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |8             |68              |
# |2020-11-01|2   |2                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |9             |77              |
# |2020-11-02|2   |2                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |10            |86              |
# |2020-11-03|1   |2                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |11            |96              |
# |2020-11-04|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |12            |106             |
# |2020-11-05|1   |1                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |13            |116             |
# |2020-11-06|1   |1                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |14            |126             |
# |2020-11-07|1   |1                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |15            |136             |
# |2020-11-08|1   |1                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |16            |146             |
# |2020-11-09|1   |1                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |17            |156             |
# |2020-11-10|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |18            |166             |
# |2020-11-11|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |19            |176             |
# |2020-11-12|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |20            |186             |
# |2020-11-13|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |21            |196             |
# |2020-11-14|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |22            |206             |
# |2020-11-15|1   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |23            |216             |
# |2020-11-16|2   |1                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |24            |225             |
# |2020-11-17|2   |2                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |25            |234             |
# |2020-11-18|3   |2                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |26            |242             |
# |2020-11-19|3   |3                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |27            |250             |
# |2020-11-20|4   |3                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |28            |257             |
# |2020-11-21|4   |4                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |29            |264             |
# |2020-11-22|4   |4                |1             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |30            |271             |
# |2020-11-23|3   |4                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |31            |279             |
# |2020-11-24|2   |3                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |32            |288             |
# |2020-11-25|3   |2                |3             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |33            |296             |
# |2020-11-26|4   |3                |3             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |34            |303             |
# |2020-11-27|4   |4                |4             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |35            |310             |
# |2020-11-28|4   |4                |4             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |36            |317             |
# |2020-11-29|3   |4                |4             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |37            |325             |
# |2020-11-30|3   |3                |3             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |38            |333             |
# |2020-12-01|4   |3                |2             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |39            |340             |
# |2020-12-02|4   |4                |3             |The Queenâs Gambit        |TV Show|Yes              |Oct 23, 2020        |40            |347             |
# +----------+----+-----------------+--------------+----------------------------+-------+-----------------+--------------------+--------------+----------------+
# only showing top 50 rows

# %% [markdown]
# > You can notice the result is wrong too

# %% [markdown]
# ## Example 2
#
# Now lets create a parquet file with special characters

# %%
data_list = [('Johnçë', 28),
             ('Alice', 24),
             ('âêîôû', 32)]
rdd = spark.sparkContext.parallelize(data_list)
specDf = spark.createDataFrame(rdd, ["Name", "Age"])

# %%
specDf.show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Johnçë| 28|
# | Alice| 24|
# | âêîôû| 32|
# +------+---+

# %%
filePath2 = "/home/onyxia/work/out_parquet"

# %%
specDf.coalesce(1).write.mode("overwrite").parquet(filePath2)
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Johnçë| 28|
# | Alice| 24|
# | âêîôû| 32|
# +------+---+

# %% [markdown]
# > We write the dataframe into a parquet file

# %%
! ls /home/onyxia/work/out_parquet
# Out:
# part-00000-4ce45397-dc47-4713-8866-d94b62896e88-c000.snappy.parquet  _SUCCESS

# %% [markdown]
# ### Read the parquet file with spark

# %%
newDf = spark.read.parquet(filePath2)
newDf.show(5)
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Johnçë| 28|
# | Alice| 24|
# | âêîôû| 32|
# +------+---+

# %% [markdown]
# ### Read the parquet file with pandas

# %%
pdf1 = pd.read_parquet(filePath2)

# %%
pdf1.head()
# Out:
#      Name  Age
# 0  Johnçë   28
# 1   Alice   24
# 2   âêîôû   32
